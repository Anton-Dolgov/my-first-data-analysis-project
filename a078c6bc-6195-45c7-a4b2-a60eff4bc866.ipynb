# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Антон, приветствую!</b>
#
# Буду рада с тобой познакомиться. Меня зовут Евгения Маракова и я буду ревьюером твоего проекта. Если ты не против, то предлагаю общаться на "ты":) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# В процессе работы ты встретишь комментарии <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Что они значат, смотри ниже:
#     <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Можно лучше⚠️:</b> Решение на этом шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>Необходимо исправить❌:</b>
#  Решение на этом шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев мой комментарий, не удаляй его, он будет очень полезен в случае повторной проверки работы😊
#
# Свой комментарий помечай так, как показано ниже, тогда нам будет легче вести диалог, а мне выполнить повторную проверку проекта.
#     <div class="alert alert-info"> <b>Комментарий студента: </b> </div>

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Антон, молодец, отлично выполнил предобработку!
# </div>

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
data.head(10)# Ваш код будет здесь. Вы можете создавать новые ячейки.
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0     926.185831         27    высшее             0
# 6         0    2879.202052         43    высшее             0
# 7         0     152.779569         50   среднее             1
# 8         2    6929.865299         35    высшее             0
# 9         0    2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# ...

# %% [markdown]
# **Вывод:**

# %% [markdown]
# #я считаю что, для оценки этой зависимости необходимо разбить данные на группы по статусу наличия детей:Нет детей, есть дети, и многодетные(3 и более детей). После чего взять даныне по группам сколько заёмщиков и сколько просрочек и вывести данные в процентах, так как колличественные показатели тут не релеванты

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отличная идея!
# </div>

# %%
def children_category(children):
    if 1 <= children <= 2:
        return 'есть дети'
    if children >= 3:
        return 'многодетная семья'
    return 'нет детей'# создаём функцию для разделения по группа по колличеству детей.

# %%
data['children_rank'] = data['children'].apply(children_category) #создаём столбец, что бы хранить статус по критерию наличия детей

# %%
data.head(10) #проверяем корректность данных
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0     926.185831         27    высшее             0
# 6         0    2879.202052         43    высшее             0
# 7         0     152.779569         50   среднее             1
# 8         2    6929.865299         35    высшее             0
# 9         0    2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# ...

# %%
# Создаем сводную таблицу
debt_children = data.pivot_table(index='children_rank', columns='debt', values='gender', aggfunc='count')
# Анализ будем проводить по следующим столбам
debt_children.columns = ['no_debt', 'debt']
# Считаем долю должников
debt_children['share_of_debtors'] = debt_children['debt'] / (debt_children['debt'] + debt_children['no_debt'])
# Считаем долю должников в процентах
debt_children['share_of_debtors'] = debt_children['share_of_debtors'].map('{:.1%}'.format)
# Сортируем по столбцу доля должников по убыванию
debt_children.sort_values(by='share_of_debtors', ascending=False)
# Out:
#                    no_debt  debt share_of_debtors
# children_rank
# есть дети             6222   638             9.3%
# многодетная семья      349    31             8.2%
# нет детей            13028  1063             7.5%

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Супер, информативная сводная таблица получилась!
#
# </div>

# %% [markdown]
# **Вывод:** мы видим, что у клиентов без детей самый низкий процент задолжностей, при этом "нет детей" самая большая по колличеству заёмщиков группа, тем самым по этим данным они самые благонадёжные. /n
# Группа "есть дети" - являются самыми не благонадёжными заёмщиками, "многодетные" берут кредиты меньше всего и процент возврата у них выше чем у "есть дети". Возмжно, есть смысл это связать с "материнским капиталом" и другими субсидиями, но это не точно. /n
# Для более точной оценки хотелось бы знать срок просрочки и сумму.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Согласна, без дополнительных данных сложно что-то утверждать. Ты верно обратил внимание, что выборки несбалансированны, поэтому для выявления зависимости можно не учитывать многодетные семьи. Таким образом, бездетные семьи более ответственные!
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>Необходимо исправить❌:</b>
# Антон, упущено задание "Есть ли зависимость между семейным положением и возвратом кредита в срок?"
# </div>

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
#Да,и правда пропустил)
#Давай попробуем по другому

# %%
children_from_debt = data.groupby('family_status')['debt'].sum() / data.groupby('family_status')['debt'].count()
children_from_debt = children_from_debt.map('{:.2%}'.format)
children_from_debt.sort_values( ascending=False)
# Out:
# family_status
# Не женат / не замужем    9.76%
# гражданский брак         9.31%
# женат / замужем          7.56%
# в разводе                7.06%
# вдовец / вдова           6.62%
# Name: debt, dtype: object

# %% [markdown]
# Вывод: так как данная таблица учитывает только итоговые проценты, то можем сделать следующие выводы: люди которые не состоят в браке или имеют гражданский брак чаще не возвращают кредиты нежели люди состоящие в оформленных отношениях или уже кто прошел этот этап. Возможно это связанно с тем, что свободные люди чаще берут кредиты на "непродуманные инициативы", в то время как семейные пары берут кредит на обдуманные и взвещенные покупки.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Абсолютно правильно, заемщики состоящие или состоявшие в браке реже допускают просрочку!
#
# </div>

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %% [markdown]
# У нас уже есть разделение по уровню ходода /n
# 0–30000 — 'E';
# 30001–50000 — 'D';
# 50001–200000 — 'C';
# 200001–1000000 — 'B';
# 1000001 и выше — 'A'.
# достаточно сделать сводную таблицу

# %%
# Создаем таблицу методом pivot()
debt_total_income = data.pivot_table(index='total_income_category', columns='debt', values='gender', aggfunc='count')
# Создаем столбцы
debt_total_income.columns = ['no_debt', 'debt']
# Считаем долю должников
debt_total_income['share_of_debtors'] = debt_total_income['debt'] / (debt_total_income['debt'] + debt_total_income['no_debt'])
# Считаем долю должников в процентах
debt_total_income['share_of_debtors'] = debt_total_income['share_of_debtors'].map('{:.1%}'.format)
# Сортируем по столбцу доля лолжников по убыванию
debt_total_income.sort_values(by='share_of_debtors', ascending=False)# Ваш код будет здесь. Вы можете создавать новые ячейки.
# Out:
#                        no_debt  debt share_of_debtors
# total_income_category
# E                           20     2             9.1%
# C                        14568  1353             8.5%
# A                           23     2             8.0%
# B                         4660   354             7.1%
# D                          328    21             6.0%

# %% [markdown]
# **Вывод:** По процентному соотношеннию, самые не благонадёжные заёмщики- люди с статусом "Е", из-за малого дохода они не могут выплатить заёмы, но и колличество таких заёщиков минимально. Тоже можно и сказать про группу "А"- мало заёмщиков и относительно большой процент не возврата. Эти группы берут мало займов, явно на разные нужны, но и процент возврата +- идентичный.
# Чаще всего займы берут клиенты категории "С" и процент не возврата у них довольно высок, возможно есть смысл обратить внимание на данную группу граждан и как-то изменить скоринг
# Не смотря на малый доход, группу "D" можно отнести к благонадёжным заёмщиков, но тут нужно смотреть "на дистанции",возможно, когда заёмщиков станет по колличеству равному группе "С" ситуация изменится в худщую сторону

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Можно лучше⚠️:</b> И какую зависимость мы наблюдаем? Антон, стоит обратить внимание на несбалансированность выборок. Сравни, пожалуйста, две самые многочисленные выборки B и C для выявления зависимости.
# </div>

# %% [markdown]
# Если провдить анализ по саым многочисленным выборкам B и С мы можем сделать выбор, что люди со "средним достатком" чаще всего берут кредиты и имею достаточно высокий процент не возврата. Это можно связать с "переоценкой" собственных сил. При этом, люди в категории С чаще всего берут кредиты и в колличественном составе чаще не возвращают

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Хорошо!
#
# </div>

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %% [markdown]
# Выше уже разбивали причину займа на категории,на основании этих данных создадим сводную таблицу

# %%
# Создаем таблицу методом pivot_table()
debt_purpose_category = data.pivot_table(index='purpose_category', columns='debt', values='gender', aggfunc='count')
# Создаем столбцы
debt_purpose_category.columns = ['no_debt', 'debt']
# Считаем долю должников
debt_purpose_category['share_of_debtors'] = debt_purpose_category['debt'] / (debt_purpose_category['debt'] + debt_purpose_category['no_debt'])
# Считаем долю должнико в процентах
debt_purpose_category['share_of_debtors'] = debt_purpose_category['share_of_debtors'].map('{:.1%}'.format)
# Сортируем по столбцу доля лолжников по убыванию
debt_purpose_category.sort_values(by='share_of_debtors', ascending=False)# Ваш код будет здесь. Вы можете создавать новые ячейки.

# %% [markdown]
# **Вывод:** Операции с недвижимостью - имеют самый низкий процент с задолжностью. Это можно связать с многими факторами: начиная от того, что это. в большинсвет случаев, осознанный поступок, заканчивая тем, что её берут семейные люди где достаток имеют 2 человека.
# Самые не благонадёжные группу "операции с автомобилем" и "получения образования": возможно берут люди с не достаточным доходом, которые не оценили стоимость и обслуживания автомобиля или хватило только на несколько курсов обучения(много доп расходов, проживание, питание и т.д.)
# p.s. группа "проведение свадьбы" https://i.pinimg.com/originals/2f/59/12/2f5912b30089c1a251796c7097a897a6.png

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Молодец, верно определил более и менее рискованные для банка категории заемщиков по целям кредита! Отличная картинка:))
# </div>

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %% [markdown]
# *Ответ:* у нас были пропуски в 2х группах: days_employed и total_income
# Если брать человеческий фактор:
# - не корректная обработка данных на входе
# - не желание клиентов указывать некоторые данные(хотя как они могут тогда получить займ)
# - не корректный ввод данных(опять же, как они тогда могли получить кредит)
# Технический фактор:
# - ошибки при переносе данных
# - ошибки в самом файле(вруг что-то с бэком случилось)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Супер, именно человеческий и технический факторы, в основном, влияют на появление пропусков. Здорово, что указал столбцы с пропущенными значениями!
# </div>

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ:*  Медиана устройчива к выбросам, нежели просто среднее значение. Так как мы это делали для схожих групп можем и предположить, что распределение должно быть идентичным

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Совершенно верно, медиана менее чувствительна к выбросам!
# </div>

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# Можем сделать следующие первичные выводы:
# - заёмщики с детьми чаще не возвращают кредиты
# - Категория граждан с уровнем дохода "С" чаще всего берут кредиты и у них высокий уровень не возврата кредитов
# - Граждане, берущие кредиты на получение образования и операции с автомобилем чаще всего не возвращают кредиты

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
# <b>Необходимо исправить❌:</b>
# Антон, общий вывод - обязательный и важный элемент работы. Его нужно сформулировать, взяв основные результаты из всех шагов проекта. Начать нужно с того, с какими данными мы работали и какие действия провели на этапе предобработки, а закончить выявленными при ответе на вопросы зависимостями и рекомендациями заказчику по улучшению сбора данных и скоринга. Заказчик, зачастую, читает только общий вывод исследования - поэтому он должен быть максимально информативным.
# </div>

# %% [markdown]
# Проведя данну работу мы сделали сдедующее:
# -обнаружили, что есть пропущенные и отрицательные значения, с помощью метода fillna() заменили пропущенные значения на медианное значение, так как именно оно не устойчиво к выбросам значений.
# -избавились от отрицательных значений методом abs()
# -для удобства анализа данных привели данные с вещественным типом данных к целочисленному методом astype(int)
# -сгруппировали цели кредита из "свободной формы" в более удобную для анализа
# -вывели зависимости долга от колличества детей
# -вывели зависимость долга от семейного статуса
# -вывели зависимость долга от дохода
# -вывели зависимость долга от цели кредита
#
# По анализу данных можем сделать следующие выводы:
# Наличие детей повышает вероятность стать должником.
# Холостые и живущие в граждансокм браке пары больше подвержены риску стать должниками.
# Категория граждан со средним доходом (50001–200000) больше подвержены риску стать должниками.
# Граждане, берущие кредиты на получение образования и операции с автомобилем больше подвержены риску стать должниками.
#
# К рекомендациями могу отнести:
# -включение в данные сумм не возврата, так как это важный критерий анализа групп риска
# -включить регионы/города где брали кредиты
# -ввести единую форму заполнения данных, для более простого анализа данных(сгрупировать цели, сделать так что бы не появлялись минуса, разобраться с данными по безработным и старикам)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2<a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Антон, привет! Молодец, оперативно и верно откорректировал проект. Работа принята, удачи в обучении!)
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
# Антон, давай подведем итоги. Ты большой молодец, что старался и проделал такую большую работу. Шаг 1 и 2 ты выполнил без проблем, что очень хорошо:)
#
#     Разберем над чем стоит поработать:
#
#     1. Рассмотреть зависимость между семейным положением и возвратом кредита в срок.
#
#     2. Оформить общий вывод.
#
#     3. Рекомендую:
#     - учитывать несбалансированность выборок.
#
#     Пересмотри работу и исправь ошибки. Обязательно пиши, если я могу тебе еще чем-то помочь. Удачи!)
